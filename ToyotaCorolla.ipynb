# %%
import pandas as pd

# %%
tc = pd.read_csv('ToyotaCorolla.csv',encoding= 'unicode_escape')

# %%
tc.head(10)
# Out:
#    Id                                           Model  Price  Age_08_04  \
# 0   1   TOYOTA Corolla 2.0 D4D HATCHB TERRA 2/3-Doors  13500         23
# 1   2   TOYOTA Corolla 2.0 D4D HATCHB TERRA 2/3-Doors  13750         23
# 2   3   TOYOTA Corolla 2.0 D4D HATCHB TERRA 2/3-Doors  13950         24
# 3   4   TOYOTA Corolla 2.0 D4D HATCHB TERRA 2/3-Doors  14950         26
# 4   5     TOYOTA Corolla 2.0 D4D HATCHB SOL 2/3-Doors  13750         30
# 5   6     TOYOTA Corolla 2.0 D4D HATCHB SOL 2/3-Doors  12950         32
# 6   7   TOYOTA Corolla 2.0 D4D 90 3DR TERRA 2/3-Doors  16900         27
# 7   8   TOYOTA Corolla 2.0 D4D 90 3DR TERRA 2/3-Doors  18600         30
# 8   9     TOYOTA Corolla 1800 T SPORT VVT I 2/3-Doors  21500         27
# 9  10     TOYOTA Corolla 1.9 D HATCHB TERRA 2/3-Doors  12950         23
#
#    Mfg_Month  Mfg_Year     KM Fuel_Type   HP  Met_Color  ... Central_Lock  \
# 0         10      2002  46986    Diesel   90          1  ...            1
# ...

# %%
tc.shape
# Out:
# (1436, 38)

# %%
tc.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1436 entries, 0 to 1435
# Data columns (total 38 columns):
# Id                  1436 non-null int64
# Model               1436 non-null object
# Price               1436 non-null int64
# Age_08_04           1436 non-null int64
# Mfg_Month           1436 non-null int64
# Mfg_Year            1436 non-null int64
# KM                  1436 non-null int64
# Fuel_Type           1436 non-null object
# HP                  1436 non-null int64
# Met_Color           1436 non-null int64
# Color               1436 non-null object
# Automatic           1436 non-null int64
# cc                  1436 non-null int64
# Doors               1436 non-null int64
# Cylinders           1436 non-null int64
# Gears               1436 non-null int64
# Quarterly_Tax       1436 non-null int64
# Weight              1436 non-null int64
# Mfr_Guarantee       1436 non-null int64
# BOVAG_Guarantee     1436 non-null int64
# Guarantee_Period    1436 non-null int64
# ...

# %%
tc.describe()
# Out:
#                 Id         Price    Age_08_04    Mfg_Month     Mfg_Year  \
# count  1436.000000   1436.000000  1436.000000  1436.000000  1436.000000
# mean    721.555014  10730.824513    55.947075     5.548747  1999.625348
# std     416.476890   3626.964585    18.599988     3.354085     1.540722
# min       1.000000   4350.000000     1.000000     1.000000  1998.000000
# 25%     361.750000   8450.000000    44.000000     3.000000  1998.000000
# 50%     721.500000   9900.000000    61.000000     5.000000  1999.000000
# 75%    1081.250000  11950.000000    70.000000     8.000000  2001.000000
# max    1442.000000  32500.000000    80.000000    12.000000  2004.000000
#
#                   KM           HP    Met_Color    Automatic           cc  ...  \
# count    1436.000000  1436.000000  1436.000000  1436.000000   1436.00000  ...
# mean    68533.259749   101.502089     0.674791     0.055710   1576.85585  ...
# std     37506.448872    14.981080     0.468616     0.229441    424.38677  ...
# ...

# %%
import seaborn as sns
import matplotlib.pyplot as plt
import numpy as np
# %matplotlib inline

# %%
data = tc[["Price","Age_08_04","KM","HP","cc","Doors","Gears","Quarterly_Tax","Weight"]]

# %%
sns.pairplot(data=data)
plt.show()

# %%
data.head(10)
# Out:
#    Price  Age_08_04     KM   HP    cc  Doors  Gears  Quarterly_Tax  Weight
# 0  13500         23  46986   90  2000      3      5            210    1165
# 1  13750         23  72937   90  2000      3      5            210    1165
# 2  13950         24  41711   90  2000      3      5            210    1165
# 3  14950         26  48000   90  2000      3      5            210    1165
# 4  13750         30  38500   90  2000      3      5            210    1170
# 5  12950         32  61000   90  2000      3      5            210    1170
# 6  16900         27  94612   90  2000      3      5            210    1245
# 7  18600         30  75889   90  2000      3      5            210    1245
# 8  21500         27  19700  192  1800      3      5            100    1185
# 9  12950         23  71138   69  1900      3      5            185    1105

# %%
def Normalize(data):
    return ((data - data.min())/(data.max()-data.min()))

data = data.apply(Normalize)

data.head(10)
# Out:
#       Price  Age_08_04        KM        HP        cc     Doors     Gears  \
# 0  0.325044   0.278481  0.193355  0.170732  0.047619  0.333333  0.666667
# 1  0.333925   0.278481  0.300149  0.170732  0.047619  0.333333  0.666667
# 2  0.341030   0.291139  0.171647  0.170732  0.047619  0.333333  0.666667
# 3  0.376554   0.316456  0.197528  0.170732  0.047619  0.333333  0.666667
# 4  0.333925   0.367089  0.158433  0.170732  0.047619  0.333333  0.666667
# 5  0.305506   0.392405  0.251026  0.170732  0.047619  0.333333  0.666667
# 6  0.445826   0.329114  0.389347  0.170732  0.047619  0.333333  0.666667
# 7  0.506217   0.367089  0.312298  0.170732  0.047619  0.333333  0.666667
# 8  0.609236   0.329114  0.081066  1.000000  0.034014  0.333333  0.666667
# 9  0.305506   0.278481  0.292746  0.000000  0.040816  0.333333  0.666667
#
#    Quarterly_Tax    Weight
# 0       0.723485  0.268293
# 1       0.723485  0.268293
# 2       0.723485  0.268293
# 3       0.723485  0.268293
# ...

# %%
def vif_cal(input_data, dependent_col):
    
    vif_df = pd.DataFrame( columns = ['Var', 'Vif'])
    x_vars=input_data.drop([dependent_col], axis=1)
    
    xvar_names=x_vars.columns
    
    for i in range(0,xvar_names.shape[0]):
        y=x_vars[xvar_names[i]] 
        x=x_vars[xvar_names.drop(xvar_names[i])]
        rsq=sm.OLS(y,x).fit().rsquared  
        vif=round(1/(1-rsq),2)
        vif_df.loc[i] = [xvar_names[i], vif]
        
        
    return vif_df.sort_values(by = 'Vif', axis=0, ascending=False, inplace=False)

# %%
from sklearn.linear_model import LinearRegression
from sklearn.model_selection import train_test_split
from sklearn.metrics import mean_squared_error,r2_score

import statsmodels.api as sm

# %%
xTrain,xTest, yTrain,yTest = train_test_split(
    data[['Age_08_04','KM','HP','cc','Doors','Gears','Quarterly_Tax','Weight']]
    ,data.Price,
    test_size=0.2)

linreg = LinearRegression()

# %%
def PredFun(trainX,trainY):
    trainX = sm.add_constant(trainX)
    
    smLM = sm.OLS(trainY,trainX).fit()
    
    return smLM

# %%
lm = PredFun(trainX = xTrain,trainY= yTrain)
# Out:
# /Users/anupprakash/Anaconda4/anaconda3/lib/python3.7/site-packages/numpy/core/fromnumeric.py:2495: FutureWarning: Method .ptp is deprecated and will be removed in a future version. Use numpy.ptp instead.
#   return ptp(axis=axis, out=out, **kwargs)

# %%
lm.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ...
# Dep. Variable:                  Price   R-squared:                       0.868
# Model:                            OLS   Adj. R-squared:                  0.867
# Method:                 Least Squares   F-statistic:                     938.8
# Date:                Fri, 07 Feb 2020   Prob (F-statistic):               0.00
# Time:                        19:33:43   Log-Likelihood:                 1943.6
# No. Observations:                1148   AIC:                            -3869.
# Df Residuals:                    1139   BIC:                            -3824.
# Df Model:                           8
# Covariance Type:            nonrobust
# ...
#                     coef    std err          t      P>|t|      [0.025      0.975]
# ---------------------------------------------------------------------------------
# ...

# %%
vif_cal(input_data = data, dependent_col='Price')
# Out:
#              Var    Vif
# 5          Gears  28.13
# 0      Age_08_04  16.61
# 6  Quarterly_Tax   8.53
# 2             HP   8.10
# 1             KM   7.58
# 7         Weight   7.27
# 4          Doors   5.80
# 3             cc   1.66

# %%
xTrain = xTrain.drop('Doors',1)

# %%
lm = PredFun(trainX = xTrain,trainY= yTrain)

# %%
lm.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ...
# Dep. Variable:                  Price   R-squared:                       0.868
# Model:                            OLS   Adj. R-squared:                  0.868
# Method:                 Least Squares   F-statistic:                     1074.
# Date:                Fri, 07 Feb 2020   Prob (F-statistic):               0.00
# Time:                        19:33:43   Log-Likelihood:                 1943.6
# No. Observations:                1148   AIC:                            -3871.
# Df Residuals:                    1140   BIC:                            -3831.
# Df Model:                           7
# Covariance Type:            nonrobust
# ...
#                     coef    std err          t      P>|t|      [0.025      0.975]
# ---------------------------------------------------------------------------------
# ...

# %%
vif_cal(input_data = data.drop('Doors',1), dependent_col='Price')
# Out:
#              Var    Vif
# 4          Gears  27.06
# 0      Age_08_04  16.43
# 5  Quarterly_Tax   8.52
# 2             HP   8.04
# 1             KM   7.58
# 6         Weight   6.70
# 3             cc   1.66

# %%
xTrain = xTrain.drop('Gears',1)

# %%
lm = PredFun(trainX = xTrain,trainY= yTrain)

# %%
lm.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ...
# Dep. Variable:                  Price   R-squared:                       0.867
# Model:                            OLS   Adj. R-squared:                  0.866
# Method:                 Least Squares   F-statistic:                     1241.
# Date:                Fri, 07 Feb 2020   Prob (F-statistic):               0.00
# Time:                        19:33:43   Log-Likelihood:                 1938.5
# No. Observations:                1148   AIC:                            -3863.
# Df Residuals:                    1141   BIC:                            -3828.
# Df Model:                           6
# Covariance Type:            nonrobust
# ...
#                     coef    std err          t      P>|t|      [0.025      0.975]
# ---------------------------------------------------------------------------------
# ...

# %%
vif_cal(input_data = data.drop(['Doors','Gears'],1), dependent_col='Price')
# Out:
#              Var    Vif
# 0      Age_08_04  10.38
# 4  Quarterly_Tax   7.63
# 1             KM   7.58
# 5         Weight   6.50
# 2             HP   5.19
# 3             cc   1.65

# %%
xTrain.head(10)
# Out:
#       Age_08_04        KM        HP        cc  Quarterly_Tax    Weight
# 863    0.746835  0.264948  0.138211  0.000000       0.189394  0.024390
# 235    0.468354  0.250322  0.333333  0.020408       0.250000  0.121951
# 440    0.670886  0.317981  0.333333  0.020408       0.189394  0.056911
# 655    0.734177  0.467899  0.333333  0.020408       0.000000  0.105691
# 57     0.316456  0.176951  0.227642  0.006803       0.250000  0.178862
# 458    0.620253  0.289874  0.000000  0.040816       0.628788  0.170732
# 234    0.506329  0.251026  0.333333  0.020408       0.250000  0.121951
# 1380   0.987342  0.228083  0.333333  0.020408       0.250000  0.121951
# 3      0.316456  0.197528  0.170732  0.047619       0.723485  0.268293
# 654    0.810127  0.470710  0.170732  0.047619       0.170455  0.422764

# %%
reg = linreg.fit(xTrain,yTrain)

# %%
print(reg.intercept_)
print(reg.coef_)
# Out:
# 0.42948392901127974
# [-0.33941081 -0.16645171  0.13049951 -0.0106649   0.00850836  0.37236019]

# %%
xTest = xTest.drop(['Doors','Gears'],1)

# %%
yPred = reg.predict(xTest)

# %%
finalData = pd.DataFrame({'Acutal':yTest,'Predicted':yPred})

# %%
plt.figure(figsize=(20,9))

sns.lineplot(data=finalData)

plt.show()

# %%
mse = mean_squared_error(yTest,yPred)
r2= r2_score(yTest,yPred)

# %%
print(mse)
print(r2)
# Out:
# 0.003476364403107395
# 0.8455667259394496
