# %%
import seaborn as sns
import pandas as pd
import matplotlib.pyplot as plt

# %%
data=pd.read_csv('/Users/anupprakash/Desktop/DataScienceDataSets/Assignment1/Cars.csv')
data.head(10)
# Out:
#    HP        MPG  VOL          SP         WT
# 0  49  53.700681   89  104.185353  28.762059
# 1  55  50.013401   92  105.461264  30.466833
# 2  55  50.013401   92  105.461264  30.193597
# 3  70  45.696322   92  113.461264  30.632114
# 4  53  50.504232   92  104.461264  29.889149
# 5  70  45.696322   89  113.185353  29.591768
# 6  55  50.013401   92  105.461264  30.308480
# 7  62  46.716554   50  102.598513  15.847758
# 8  62  46.716554   50  102.598513  16.359484
# 9  80  42.299078   94  115.645204  30.920154

# %%
sns.distplot(data['HP'])
plt.show()

# %%
'''sns.distplot(
    a,
    bins=None,
    hist=True,
    kde=True,
    rug=False,
    fit=None,
    hist_kws=None,
    kde_kws=None,
    rug_kws=None,
    fit_kws=None,
    color=None,
    vertical=False,
    norm_hist=False,
    axlabel=None,
    label=None,
    ax=None,
)'''
# Out:
# 'sns.distplot(\n    a,\n    bins=None,\n    hist=True,\n    kde=True,\n    rug=False,\n    fit=None,\n    hist_kws=None,\n    kde_kws=None,\n    rug_kws=None,\n    fit_kws=None,\n    color=None,\n    vertical=False,\n    norm_hist=False,\n    axlabel=None,\n    label=None,\n    ax=None,\n)'

# %%
sns.distplot(data.HP,bins=20)
#bins is for the number of the frequency line we want in the graph
plt.show()

# %%
sns.distplot(data['HP'],hist=False)
# hist is use to eleminate the bars from the graph
plt.show()

# %%
sns.distplot(data['HP'],rug=True)
plt.show()

# %%
sns.distplot(data['HP'],fit=norm)
# fit is use to generally represet normalize kernel density estimator (kde)
# it work only with scikit
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-23-29c295277527> in <module>
# ----> 1 sns.distplot(data['HP'],fit=norm)
#       2 plt.show()
#
# NameError: name 'norm' is not defined

# %%
sns.distplot(data['HP'],color='k')
plt.show()

# %%
sns.distplot(data['HP'],label='HP')
plt.legend(loc=2)
plt.show()

# %%
sns.set(style='darkgrid')
plt.figure(figsize=(18,9))

sns.distplot(data['HP'])
sns.distplot(data['MPG'])
sns.distplot(data['SP'])

plt.grid(color='k',linewidth=2,linestyle=':')
plt.show()
