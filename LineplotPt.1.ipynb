# %%
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np
import pandas as pd
from matplotlib import style

# %%
dataset=pd.read_csv("/Users/anupprakash/Desktop/DataScienceDataSets/Assignment1/Cars.csv")

# %%
dataset.head(5)
# Out:
#    HP        MPG  VOL          SP         WT
# 0  49  53.700681   89  104.185353  28.762059
# 1  55  50.013401   92  105.461264  30.466833
# 2  55  50.013401   92  105.461264  30.193597
# 3  70  45.696322   92  113.461264  30.632114
# 4  53  50.504232   92  104.461264  29.889149

# %%
sns.lineplot(x='HP',y='MPG',data=dataset)
plt.show()

# %%
style.use('ggplot')
sns.lineplot(x='MPG',y='HP',data=dataset,label='MPG')
plt.legend(loc=2)
plt.show()

# %%
sns.lineplot(x='MPG',y='VOL',data=dataset)
plt.show()
