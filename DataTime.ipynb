# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %matplotlib inline

# %%
data = pd.read_csv('/Users/anupprakash/Documents/DeepLearningKeras/Dataweekends-zero_to_deep_learning_video-master/data/international-airline-passengers.csv')

# %%
data.head()
# Out:
#      Month  Thousand Passengers
# 0  1949-01                  112
# 1  1949-02                  118
# 2  1949-03                  132
# 3  1949-04                  129
# 4  1949-05                  121

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 144 entries, 0 to 143
# Data columns (total 2 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   Month                144 non-null    object
#  1   Thousand Passengers  144 non-null    int64
# dtypes: int64(1), object(1)
# memory usage: 2.4+ KB

# %%
data['Month'] = pd.to_datetime(data.Month)

# %%
data['Month']
# Out:
# 0     1949-01-01
# 1     1949-02-01
# 2     1949-03-01
# 3     1949-04-01
# 4     1949-05-01
#          ...
# 139   1960-08-01
# 140   1960-09-01
# 141   1960-10-01
# 142   1960-11-01
# 143   1960-12-01
# Name: Month, Length: 144, dtype: datetime64[ns]

# %%
data['Month'].dt.month
# Out:
# 0       1
# 1       2
# 2       3
# 3       4
# 4       5
#        ..
# 139     8
# 140     9
# 141    10
# 142    11
# 143    12
# Name: Month, Length: 144, dtype: int64

# %%
data['Month'].dt.dayofyear
# Out:
# 0        1
# 1       32
# 2       60
# 3       91
# 4      121
#       ...
# 139    214
# 140    245
# 141    275
# 142    306
# 143    336
# Name: Month, Length: 144, dtype: int64

# %%
data.set_index('Month')
# Out:
#             Thousand Passengers
# Month
# 1949-01-01                  112
# 1949-02-01                  118
# 1949-03-01                  132
# 1949-04-01                  129
# 1949-05-01                  121
# ...                         ...
# 1960-08-01                  606
# 1960-09-01                  508
# 1960-10-01                  461
# 1960-11-01                  390
# 1960-12-01                  432
#
# [144 rows x 1 columns]

# %%
sns.set_style('darkgrid')
plt.figure(figsize=(19,9))
sns.distplot(data['Thousand Passengers'],)
plt.xlabel('Thousand Passengers',fontsize=20)
plt.ylabel('Frequency Panssengers')
plt.show()

# %%
#sns.set_style('darkgrid')
plt.figure(figsize=(19,9))
sns.scatterplot(x='Month',y='Thousand Passengers',data=data)
plt.xlabel('Month',fontsize=20)
plt.ylabel('Thousand passengers',fontsize=20)
plt.show()
