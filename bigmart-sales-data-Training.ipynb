# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %matplotlib inline

# %%
data = pd.read_csv('/Users/anupprakash/Documents/ExcelRDataScience/DataSetFile/bigmart-sales-data/Train.csv')

# %%
data.head(10)
# Out:
#   Item_Identifier  Item_Weight Item_Fat_Content  Item_Visibility  \
# 0           FDA15        9.300          Low Fat         0.016047
# 1           DRC01        5.920          Regular         0.019278
# 2           FDN15       17.500          Low Fat         0.016760
# 3           FDX07       19.200          Regular         0.000000
# 4           NCD19        8.930          Low Fat         0.000000
# 5           FDP36       10.395          Regular         0.000000
# 6           FDO10       13.650          Regular         0.012741
# 7           FDP10          NaN          Low Fat         0.127470
# 8           FDH17       16.200          Regular         0.016687
# 9           FDU28       19.200          Regular         0.094450
#
#                Item_Type  Item_MRP Outlet_Identifier  \
# 0                  Dairy  249.8092            OUT049
# 1            Soft Drinks   48.2692            OUT018
# 2                   Meat  141.6180            OUT049
# ...

# %%
data.shape
# Out:
# (8523, 12)

# %%
data.drop('Item_Identifier',1,inplace= True)

# %%
data.head()
# Out:
#    Item_Weight Item_Fat_Content  Item_Visibility              Item_Type  \
# 0         9.30          Low Fat         0.016047                  Dairy
# 1         5.92          Regular         0.019278            Soft Drinks
# 2        17.50          Low Fat         0.016760                   Meat
# 3        19.20          Regular         0.000000  Fruits and Vegetables
# 4         8.93          Low Fat         0.000000              Household
#
#    Item_MRP Outlet_Identifier  Outlet_Establishment_Year Outlet_Size  \
# 0  249.8092            OUT049                       1999      Medium
# 1   48.2692            OUT018                       2009      Medium
# 2  141.6180            OUT049                       1999      Medium
# 3  182.0950            OUT010                       1998         NaN
# 4   53.8614            OUT013                       1987        High
#
#   Outlet_Location_Type        Outlet_Type  Item_Outlet_Sales
# ...

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8523 entries, 0 to 8522
# Data columns (total 11 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   Item_Weight                7060 non-null   float64
#  1   Item_Fat_Content           8523 non-null   object
#  2   Item_Visibility            8523 non-null   float64
#  3   Item_Type                  8523 non-null   object
#  4   Item_MRP                   8523 non-null   float64
#  5   Outlet_Identifier          8523 non-null   object
#  6   Outlet_Establishment_Year  8523 non-null   int64
#  7   Outlet_Size                6113 non-null   object
#  8   Outlet_Location_Type       8523 non-null   object
#  9   Outlet_Type                8523 non-null   object
#  10  Item_Outlet_Sales          8523 non-null   float64
# dtypes: float64(4), int64(1), object(6)
# memory usage: 732.6+ KB

# %%
len(data)
# Out:
# 8523

# %%
data.describe()
# Out:
#        Item_Weight  Item_Visibility     Item_MRP  Outlet_Establishment_Year  \
# count  7060.000000      8523.000000  8523.000000                8523.000000
# mean     12.857645         0.066132   140.992782                1997.831867
# std       4.643456         0.051598    62.275067                   8.371760
# min       4.555000         0.000000    31.290000                1985.000000
# 25%       8.773750         0.026989    93.826500                1987.000000
# 50%      12.600000         0.053931   143.012800                1999.000000
# 75%      16.850000         0.094585   185.643700                2004.000000
# max      21.350000         0.328391   266.888400                2009.000000
#
#        Item_Outlet_Sales
# count        8523.000000
# mean         2181.288914
# std          1706.499616
# min            33.290000
# 25%           834.247400
# 50%          1794.331000
# 75%          3101.296400
# max         13086.964800

# %%
data.describe(include='O')
# Out:
#        Item_Fat_Content              Item_Type Outlet_Identifier Outlet_Size  \
# count              8523                   8523              8523        6113
# unique                5                     16                10           3
# top             Low Fat  Fruits and Vegetables            OUT027      Medium
# freq               5089                   1232               935        2793
#
#        Outlet_Location_Type        Outlet_Type
# count                  8523               8523
# unique                    3                  4
# top                  Tier 3  Supermarket Type1
# freq                   3350               5577

# %%
plt.figure(figsize=(19,9))

sns.distplot(data.Item_Outlet_Sales,kde=False)

plt.xticks(fontsize=15,color='white')
plt.yticks(fontsize=15,color='white')

plt.xlabel('Item Outlet Sales',fontsize=15,color='white')
plt.ylabel('Units',fontsize=15,color='white')
plt.show()

# %%
plt.figure(figsize=(10,9))

sns.boxplot(data['Item_Outlet_Sales'],orient='v')

plt.ylabel('Item Outlet Sales',fontsize=15,color='white')
plt.show()

# %%
# lets see that sales is dependet on Location or not

# %%
grid = sns.FacetGrid(data,col='Outlet_Location_Type')
grid.map(sns.boxplot,'Item_Outlet_Sales',orient='v')

plt.show()
# Out:
# /Users/anupprakash/Anaconda4/anaconda3/lib/python3.7/site-packages/seaborn/axisgrid.py:728: UserWarning: Using the boxplot function without specifying `order` is likely to produce an incorrect plot.
#   warnings.warn(warning)

# %%
plt.figure(figsize=(19,9))

sns.scatterplot(x='Item_Weight',y='Item_Outlet_Sales',data=data)

plt.show()

# %%
# can't conclude anything from this scatter plot

# %%
grid = sns.FacetGrid(data,col='Item_Fat_Content',height=4,aspect=.6)
grid.map(sns.distplot,'Item_Outlet_Sales')
grid.set_xticklabels(fontsize=12,color='white')
grid.set_titles(color='white')
plt.show()

# %%
data['Item_Fat_Content'].value_counts()
# Out:
# Low Fat    5089
# Regular    2889
# LF          316
# reg         117
# low fat     112
# Name: Item_Fat_Content, dtype: int64

# %%
# it seems to be value are same but with different naming convention
# we will change it

# %%
names = {'Low Fat':"LF",'low fat':'LF','Regular':'reg'}

# %%
data['Item_Fat_Content'] = data['Item_Fat_Content'].map(names)

# %%
data['Item_Fat_Content'].value_counts()
# Out:
# LF     5201
# reg    2889
# Name: Item_Fat_Content, dtype: int64

# %%
grid = sns.FacetGrid(data,row='Item_Fat_Content',aspect=1.3,height=5)
grid.map(sns.distplot,'Item_Outlet_Sales')
grid.set_xticklabels(fontsize=13,color='white')
grid.set_yticklabels(fontsize=13,color='white')
grid.set_titles(color='white')

plt.show()

# %%
data['Item_Type'].value_counts()
# Out:
# Fruits and Vegetables    1232
# Snack Foods              1200
# Household                 910
# Frozen Foods              856
# Dairy                     682
# Canned                    649
# Baking Goods              648
# Health and Hygiene        520
# Soft Drinks               445
# Meat                      425
# Breads                    251
# Hard Drinks               214
# Others                    169
# Starchy Foods             148
# Breakfast                 110
# Seafood                    64
# Name: Item_Type, dtype: int64

# %%
plt.figure(figsize=(19,9))

sns.distplot(data['Item_MRP'])

plt.show()

# %%
plt.figure(figsize=(10,9))

sns.boxplot(data['Item_MRP'],orient='v')

plt.ylabel('MRP',fontsize=19,color='white')
plt.yticks(fontsize=15,color='white')
plt.show()

# %%
# the box plot show the data is normally distributed 
# no outliers

# %%
plt.figure(figsize=(10,9))

sns.barplot(x='Outlet_Establishment_Year',y='Item_Outlet_Sales',data=data)

plt.show()

# %%
data.isna().sum()
# Out:
# Item_Weight                  1463
# Item_Fat_Content              433
# Item_Visibility                 0
# Item_Type                       0
# Item_MRP                        0
# Outlet_Identifier               0
# Outlet_Establishment_Year       0
# Outlet_Size                  2410
# Outlet_Location_Type            0
# Outlet_Type                     0
# Item_Outlet_Sales               0
# dtype: int64

# %%
data = data.interpolate()

# %%
data['Item_Fat_Content'] = data['Item_Fat_Content'].fillna(method='ffill')

# %%
data['Outlet_Size'] = data['Outlet_Size'].fillna(method='ffill')

# %%
data.isna().sum()
# Out:
# Item_Weight                  0
# Item_Fat_Content             0
# Item_Visibility              0
# Item_Type                    0
# Item_MRP                     0
# Outlet_Identifier            0
# Outlet_Establishment_Year    0
# Outlet_Size                  0
# Outlet_Location_Type         0
# Outlet_Type                  0
# Item_Outlet_Sales            0
# dtype: int64

# %%
sns.pairplot(data)
